# %% [markdown]
# <a href="https://colab.research.google.com/github/jholiner/Talento_Tech/blob/main/Ejercicios_Jholiner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Establesco conexion
path = "/content/drive/MyDrive/Colab Notebooks/DA_Talento/data/db/ventas actividad 7-6-2024 jholiner angulo.xlsx"

# %%
#Importar la libreria pandas para manipular datos
import pandas as pd

# %%
#creamos un dataframe de pandas con los datos suministrados
df_ventas = pd.read_excel(path)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# # **subir archivos sin autorizacion de drive:**
#
# from google.colab import files
#
# uploaded = files.upload()

# %% [markdown]
# # **Creación y Lectura de DataFrames:**

# %% [markdown]
# *   pd.DataFrame(data): Crea un DataFrame a partir de datos.
# *   pd.read_csv('archivo.csv'): Lee un archivo CSV y crea un DataFrame.
#
# *   pd.read_excel('archivo.xlsx'): Lee un archivo Excel y crea un DataFrame.

# %% [markdown]
# # **Visualización y Exploración de Datos:**

# %% [markdown]
# *   df.head(): Muestra las primeras filas del DataFrame.
# *   df.tail(): Muestra las últimas filas del DataFrame.
# *   df.info(): Muestra información sobre el DataFrame, incluyendo tipos de datos y valores no nulos.
# *   df.describe(): Proporciona estadísticas descriptivas para columnas numéricas.
# *   df.shape: Devuelve una tupla con la cantidad de filas y columnas del DataFrame.
# *   df.columns: Devuelve una lista con los nombres de las columnas del DataFrame.
# *  df_nueva = df_antigua.rename(columns col1:COL1, col2:COL2): Cambia los nombres de las columnas
# * df.query("lo que se va  aconsultar") : realiza una conmsulta de algo en especifico

# %%
df_ventas.head()
# Out:
#        Fecha   Region  Producto Vendedor  Ventas
# 0 2024-02-16    Oeste  Sistemas    Kevin   32855
# 1 2024-02-05  Central  Sistemas    Karen   30633
# 2 2024-02-17    Oeste  Sistemas     Sara   23151
# 3 2024-02-04  Central  Sistemas    David   20098
# 4 2024-02-10     Este  Sistemas      Ana   13531

# %%
df_ventas.tail()
# Out:
#         Fecha   Region    Producto Vendedor  Ventas
# 14 2024-02-07     Este  Accesorios    Lucas    7667
# 15 2024-02-01  Central  Accesorios    Karen    6909
# 16 2024-02-13    Oeste  Accesorios     Sara    5442
# 17 2024-02-12    Oeste  Accesorios    Kevin    4744
# 18        NaT      NaN         NaN      NaN  239533

# %%
df_ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     18 non-null     datetime64[ns]
#  1   Region    18 non-null     object
#  2   Producto  18 non-null     object
#  3   Vendedor  18 non-null     object
#  4   Ventas    19 non-null     int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 888.0+ bytes

# %%
df_ventas.describe()
# Out:
#                      Fecha         Ventas
# count                   18      19.000000
# mean   2024-02-08 12:00:00   25214.000000
# min    2024-01-31 00:00:00    4744.000000
# 25%    2024-02-04 06:00:00    8533.500000
# 50%    2024-02-08 12:00:00   10711.000000
# 75%    2024-02-12 18:00:00   16814.500000
# max    2024-02-17 00:00:00  239533.000000
# std                    NaN   52501.045578

# %%
df_ventas.columns
# Out:
# Index(['Fecha', 'Region', 'Producto', 'Vendedor', 'Ventas'], dtype='object')

# %% [markdown]
# # **EJERCICIOS**

# %%
# Ejercicio 1: Mostrar las primeras filas del DataFrame
print("Ejercicio 1: Mostrar las primeras filas del DataFrame")
print(df_ventas.head(5))
# Out:
# Ejercicio 1: Mostrar las primeras filas del DataFrame
#        Fecha   Region  Producto Vendedor  Ventas
# 0 2024-02-16    Oeste  Sistemas    Kevin   32855
# 1 2024-02-05  Central  Sistemas    Karen   30633
# 2 2024-02-17    Oeste  Sistemas     Sara   23151
# 3 2024-02-04  Central  Sistemas    David   20098
# 4 2024-02-10     Este  Sistemas      Ana   13531

# %%
# Ejercicio 2: Calcular el Total de Ventas por Region
print("Ejercicio 2: Calcular el Total de Ventas por Region")
ventas_por_region = df_ventas.groupby("Region")["Ventas"].sum()
print(ventas_por_region)
print("/n")
print(df_ventas.head(10))
# Out:
# Ejercicio 2: Calcular el Total de Ventas por Region
# Region
# Central    90295
# Este       63555
# Oeste      85683
# Name: Ventas, dtype: int64
# /n
#        Fecha   Region      Producto Vendedor  Ventas
# 0 2024-02-16    Oeste      Sistemas    Kevin   32855
# 1 2024-02-05  Central      Sistemas    Karen   30633
# 2 2024-02-17    Oeste      Sistemas     Sara   23151
# 3 2024-02-04  Central      Sistemas    David   20098
# 4 2024-02-10     Este      Sistemas      Ana   13531
# 5 2024-02-11     Este      Sistemas    Lucas   13374
# 6 2024-02-03  Central  Dispositivos    Karen   12948
# 7 2024-02-02  Central  Dispositivos    David   11420
# 8 2024-02-14    Oeste  Dispositivos    Kevin   10711
# 9 2024-02-08     Este  Dispositivos      Ana   10348

# %%
# Ejercicio 3: Filtrar el DataFrame para mostar solo las ventas realizadas por David
print("Ejercicio 3: Filtrar el DataFrame para mostar solo las ventas realizadas por David")
ventas_david = df_ventas[df_ventas["Vendedor"]== "David"]
print(ventas_david)
# Out:
# Ejercicio 3: Filtrar el DataFrame para mostar solo las ventas realizadas por David
#         Fecha   Region      Producto Vendedor  Ventas
# 3  2024-02-04  Central      Sistemas    David   20098
# 7  2024-02-02  Central  Dispositivos    David   11420
# 13 2024-01-31  Central    Accesorios    David    8287

# %%
# Ejercicio 4: Calcular el promedio de Ventas por Region
print("Ejercicio 4: Calcular el promedio de Ventas por Region")
ventas_por_region = df_ventas.groupby("Region")["Ventas"].mean()
print(ventas_por_region)
# Out:
# Ejercicio 4: Calcular el promedio de Ventas por Region
# Region
# Central    15049.166667
# Este       10592.500000
# Oeste      14280.500000
# Name: Ventas, dtype: float64

# %%
# Ejercicio 5: Calcular el promedio de Ventas por Region con dos decimales
print("Ejercicio 5: Calcular el promedio de Ventas por Region con dos decimales")
ventas_por_region = df_ventas.groupby("Region")["Ventas"].mean().round(2)
print(ventas_por_region)
# Out:
# Ejercicio 5: Calcular el promedio de Ventas por Region con dos decimales
# Region
# Central    15049.17
# Este       10592.50
# Oeste      14280.50
# Name: Ventas, dtype: float64

# %%
# Ejercicio 6: Ordenar el DataFrame por ventas en orden Descendente
print("Ejercicio 6: Ordenar el DataFrame por ventas en orden Descendente")
df_ordenado = df_ventas.sort_values(by = "Ventas", ascending = False)
print(df_ordenado)
# Out:
# Ejercicio 6: Ordenar el DataFrame por ventas en orden Descendente
#         Fecha   Region      Producto Vendedor  Ventas
# 18        NaT      NaN           NaN      NaN  239533
# 0  2024-02-16    Oeste      Sistemas    Kevin   32855
# 1  2024-02-05  Central      Sistemas    Karen   30633
# 2  2024-02-17    Oeste      Sistemas     Sara   23151
# 3  2024-02-04  Central      Sistemas    David   20098
# 4  2024-02-10     Este      Sistemas      Ana   13531
# 5  2024-02-11     Este      Sistemas    Lucas   13374
# 6  2024-02-03  Central  Dispositivos    Karen   12948
# 7  2024-02-02  Central  Dispositivos    David   11420
# 8  2024-02-14    Oeste  Dispositivos    Kevin   10711
# 9  2024-02-08     Este  Dispositivos      Ana   10348
# 10 2024-02-06     Este    Accesorios      Ana    9323
# 11 2024-02-09     Este  Dispositivos    Lucas    9312
# 12 2024-02-15    Oeste  Dispositivos     Sara    8780
# 13 2024-01-31  Central    Accesorios    David    8287
# 14 2024-02-07     Este    Accesorios    Lucas    7667
# 15 2024-02-01  Central    Accesorios    Karen    6909
# 16 2024-02-13    Oeste    Accesorios     Sara    5442
# 17 2024-02-12    Oeste    Accesorios    Kevin    4744

# %%
# Ejercicio 7: Filtrar las filas con ventas mayores a 10000 y ordenar de mayor a menor
print("Ejercicio 7: Filtrar las filas con ventas mayores a 10000 y ordenar de mayor a menor")
df_filtrado = df_ventas[df_ventas["Ventas"] > 10000].sort_values(by = "Ventas", ascending = True)
print(df_filtrado)
print ("/n")
# Out:
# Ejercicio 7: Filtrar las filas con ventas mayores a 10000 y ordenar de mayor a menor
#         Fecha   Region      Producto Vendedor  Ventas
# 9  2024-02-08     Este  Dispositivos      Ana   10348
# 8  2024-02-14    Oeste  Dispositivos    Kevin   10711
# 7  2024-02-02  Central  Dispositivos    David   11420
# 6  2024-02-03  Central  Dispositivos    Karen   12948
# 5  2024-02-11     Este      Sistemas    Lucas   13374
# 4  2024-02-10     Este      Sistemas      Ana   13531
# 3  2024-02-04  Central      Sistemas    David   20098
# 2  2024-02-17    Oeste      Sistemas     Sara   23151
# 1  2024-02-05  Central      Sistemas    Karen   30633
# 0  2024-02-16    Oeste      Sistemas    Kevin   32855
# 18        NaT      NaN           NaN      NaN  239533
# /n

# %%
# Ejercicio 8: Eliminar la Columna (Vendedor)
print("Ejercicio 8: Eliminar la Columna Vendedor")
df_sin_vendedor = df_ventas.drop(columns=["Vendedor"])
print(df_sin_vendedor)
print ("/n")
# Out:
# Ejercicio 8: Eliminar la Columna Vendedor
#         Fecha   Region      Producto  Ventas
# 0  2024-02-16    Oeste      Sistemas   32855
# 1  2024-02-05  Central      Sistemas   30633
# 2  2024-02-17    Oeste      Sistemas   23151
# 3  2024-02-04  Central      Sistemas   20098
# 4  2024-02-10     Este      Sistemas   13531
# 5  2024-02-11     Este      Sistemas   13374
# 6  2024-02-03  Central  Dispositivos   12948
# 7  2024-02-02  Central  Dispositivos   11420
# 8  2024-02-14    Oeste  Dispositivos   10711
# 9  2024-02-08     Este  Dispositivos   10348
# 10 2024-02-06     Este    Accesorios    9323
# 11 2024-02-09     Este  Dispositivos    9312
# 12 2024-02-15    Oeste  Dispositivos    8780
# 13 2024-01-31  Central    Accesorios    8287
# 14 2024-02-07     Este    Accesorios    7667
# 15 2024-02-01  Central    Accesorios    6909
# 16 2024-02-13    Oeste    Accesorios    5442
# 17 2024-02-12    Oeste    Accesorios    4744
# 18        NaT      NaN           NaN  239533
# /n

# %% [markdown]
# # **Ejercicios 2**

# %%
#Establecemos la ruta del Dataset en el Drive
file_path = "/content/drive/MyDrive/Colab Notebooks/DA_Talento/data/db/DATASET 1.csv"

# %%
#Leemos el Dataset con la libreria Pandas
df_persona = pd.read_csv(file_path, delimiter=";")

# %%
#Imprimimos el DataFrame
print(df_persona)
# Out:
#    ID  WEIGHT  HEIGHT  AGE GENDER
# 0   1   144.5     5.9   33      M
# 1   2   167.2     5.4   45      M
# 2   3   124.1     5.2   23      F
# 3   4   144.5     5.9   33      M
# 4   5   133.2     5.7   54      F
# 5   3   124.1     5.2   23      F
# 6   5   129.2     5.3   42      M

# %%
#cambiar nombre de columnas

df_persona = df_persona.rename(columns={
                                        "WEIGHT":"ALTURA",
                                        'HEIGHT':'PESO',
                                        'AGE'   :'EDAD',
                                        'GENDER':'GENERO'})
df_persona
# Out:
#    ID  ALTURA  PESO  EDAD GENERO
# 0   1   144.5   5.9    33      M
# 1   2   167.2   5.4    45      M
# 2   3   124.1   5.2    23      F
# 3   4   144.5   5.9    33      M
# 4   5   133.2   5.7    54      F
# 5   3   124.1   5.2    23      F
# 6   5   129.2   5.3    42      M
